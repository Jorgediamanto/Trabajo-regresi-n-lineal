# %% [markdown]
# # Python_questions
# Aqui encontramos el codigo de python.

# %%
import pandas as pd

# %%
dataset = pd.read_excel("regression_data (1).xls")

# %%
dataset
# Out:
#                id       date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      7129300520 2014-10-13         3       1.00         1180      5650
# 1      6414100192 2014-12-09         3       2.25         2570      7242
# 2      5631500400 2015-02-25         2       1.00          770     10000
# 3      2487200875 2014-12-09         4       3.00         1960      5000
# 4      1954400510 2015-02-18         3       2.00         1680      8080
# ...           ...        ...       ...        ...          ...       ...
# 21592   263000018 2014-05-21         3       2.50         1530      1131
# 21593  6600060120 2015-02-23         4       2.50         2310      5813
# 21594  1523300141 2014-06-23         2       0.75         1020      1350
# 21595   291310100 2015-01-16         3       2.50         1600      2388
# 21596  1523300157 2014-10-15         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  sqft_above  sqft_basement  \
# ...

# %%
for col in dataset.columns:
    if "date" in col:
        del dataset[col]

# %%
dataset.head(10)
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  7129300520         3       1.00         1180      5650     1.0           0
# 1  6414100192         3       2.25         2570      7242     2.0           0
# 2  5631500400         2       1.00          770     10000     1.0           0
# 3  2487200875         4       3.00         1960      5000     1.0           0
# 4  1954400510         3       2.00         1680      8080     1.0           0
# 5  7237550310         4       4.50         5420    101930     1.0           0
# 6  1321400060         3       2.25         1715      6819     2.0           0
# 7  2008000270         3       1.50         1060      9711     1.0           0
# 8  2414600126         3       1.00         1780      7470     1.0           0
# 9  3793500160         3       2.50         1890      6560     2.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
numero_filas = dataset.shape[0]
numero_filas
# Out:
# 21597

# %%
#este metodo también puede ser usado
len(dataset)
# Out:
# 21597

# %% [markdown]
# 21597-1 = 21596 si excluimos los índices como fila válida

# %%
dataset["bedrooms"].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  8,  9, 11, 10, 33], dtype=int64)

# %%
dataset["bathrooms"].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 1.25, 5.25, 6.  , 0.5 , 5.5 ,
#        6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
dataset["floors"].unique()
# Out:
# array([1. , 2. , 1.5, 3. , 2.5, 3.5])

# %%
dataset["condition"].unique()
# Out:
# array([3, 5, 4, 1, 2], dtype=int64)

# %%
dataset["grade"].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13], dtype=int64)

# %%
dataset
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 2      5631500400         2       1.00          770     10000     1.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21592   263000018         3       2.50         1530      1131     3.0
# 21593  6600060120         4       2.50         2310      5813     2.0
# 21594  1523300141         2       0.75         1020      1350     2.0
# 21595   291310100         3       2.50         1600      2388     2.0
# 21596  1523300157         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
dataset2 = dataset.price.sort_values(ascending=False).head(10)
dataset2
# Out:
# 7245    7700000
# 3910    7060000
# 9245    6890000
# 4407    5570000
# 1446    5350000
# 1313    5300000
# 1162    5110000
# 8085    4670000
# 2624    4500000
# 8629    4490000
# Name: price, dtype: int64

# %%
dataset2.index
# Out:
# Int64Index([7245, 3910, 9245, 4407, 1446, 1313, 1162, 8085, 2624, 8629], dtype='int64')

# %%
dataset["price"].mean()
# Out:
# 540296.5735055795

# %%
dataset.groupby("bedrooms")["price"].mean()
# Out:
# bedrooms
# 1     3.182395e+05
# 2     4.013877e+05
# 3     4.662766e+05
# 4     6.355647e+05
# 5     7.868741e+05
# 6     8.258535e+05
# 7     9.514478e+05
# 8     1.105077e+06
# 9     8.939998e+05
# 10    8.200000e+05
# 11    5.200000e+05
# 33    6.400000e+05
# Name: price, dtype: float64

# %%
dataset.groupby("bedrooms")["sqft_living"].mean()
# Out:
# bedrooms
# 1      888.153061
# 2     1239.752899
# 3     1805.837235
# 4     2554.649666
# 5     3047.545284
# 6     3284.341912
# 7     3974.210526
# 8     3800.000000
# 9     3775.000000
# 10    3706.666667
# 11    3000.000000
# 33    1620.000000
# Name: sqft_living, dtype: float64

# %%
dataset.groupby("waterfront")["price"].mean()
# Out:
# waterfront
# 0    5.317623e+05
# 1    1.662524e+06
# Name: price, dtype: float64

# %%
dataset[["condition","grade"]].corr()
# Out:
#            condition     grade
# condition   1.000000 -0.146896
# grade      -0.146896  1.000000

# %% [markdown]
# correlacion = -0,15 , muy poca correlación

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x="condition", y="grade", data=dataset);

# %% [markdown]
# # Numero de casas en cada categoria

# %% [markdown]
# Buena representación

# %%
dataset.groupby("bedrooms").count()
# Out:
#             id  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# bedrooms
# 1          196        196          196       196     196         196   196
# 2         2760       2760         2760      2760    2760        2760  2760
# 3         9824       9824         9824      9824    9824        9824  9824
# 4         6882       6882         6882      6882    6882        6882  6882
# 5         1601       1601         1601      1601    1601        1601  1601
# 6          272        272          272       272     272         272   272
# 7           38         38           38        38      38          38    38
# 8           13         13           13        13      13          13    13
# 9            6          6            6         6       6           6     6
# 10           3          3            3         3       3           3     3
# 11           1          1            1         1       1           1     1
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("sqft_living").count()
# Out:
#              id  bedrooms  bathrooms  sqft_lot  floors  waterfront  view  \
# sqft_living
# 370           1         1          1         1       1           1     1
# 380           1         1          1         1       1           1     1
# 390           1         1          1         1       1           1     1
# 410           1         1          1         1       1           1     1
# 420           2         2          2         2       2           2     2
# ...          ..       ...        ...       ...     ...         ...   ...
# 9640          1         1          1         1       1           1     1
# 9890          1         1          1         1       1           1     1
# 10040         1         1          1         1       1           1     1
# 12050         1         1          1         1       1           1     1
# 13540         1         1          1         1       1           1     1
#
#              condition  grade  sqft_above  sqft_basement  yr_built  \
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("sqft_lot").count()
# Out:
#           id  bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# sqft_lot
# 520        1         1          1            1       1           1     1
# 572        1         1          1            1       1           1     1
# 600        1         1          1            1       1           1     1
# 609        1         1          1            1       1           1     1
# 635        1         1          1            1       1           1     1
# ...       ..       ...        ...          ...     ...         ...   ...
# 982998     1         1          1            1       1           1     1
# 1024068    1         1          1            1       1           1     1
# 1074218    1         1          1            1       1           1     1
# 1164794    1         1          1            1       1           1     1
# 1651359    1         1          1            1       1           1     1
#
#           condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %% [markdown]
# Buena representación

# %%
dataset.groupby("bathrooms").count()
# Out:
#              id  bedrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# bathrooms
# 0.50          4         4            4         4       4           4     4
# 0.75         71        71           71        71      71          71    71
# 1.00       3851      3851         3851      3851    3851        3851  3851
# 1.25          9         9            9         9       9           9     9
# 1.50       1445      1445         1445      1445    1445        1445  1445
# 1.75       3048      3048         3048      3048    3048        3048  3048
# 2.00       1930      1930         1930      1930    1930        1930  1930
# 2.25       2047      2047         2047      2047    2047        2047  2047
# 2.50       5377      5377         5377      5377    5377        5377  5377
# 2.75       1185      1185         1185      1185    1185        1185  1185
# 3.00        753       753          753       753     753         753   753
# ...

# %% [markdown]
# Buena representación

# %%
dataset.groupby("floors").count()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  waterfront   view  \
# floors
# 1.0     10673     10673      10673        10673     10673       10673  10673
# 1.5      1910      1910       1910         1910      1910        1910   1910
# 2.0      8235      8235       8235         8235      8235        8235   8235
# 2.5       161       161        161          161       161         161    161
# 3.0       611       611        611          611       611         611    611
# 3.5         7         7          7            7         7           7      7
#
#         condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# floors
# 1.0         10673  10673       10673          10673     10673         10673
# 1.5          1910   1910        1910           1910      1910          1910
# 2.0          8235   8235        8235           8235      8235          8235
# 2.5           161    161         161            161       161           161
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("waterfront").count()
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors   view  \
# waterfront
# 0           21434     21434      21434        21434     21434   21434  21434
# 1             163       163        163          163       163     163    163
#
#             condition  grade  sqft_above  sqft_basement  yr_built  \
# waterfront
# 0               21434  21434       21434          21434     21434
# 1                 163    163         163            163       163
#
#             yr_renovated  zipcode    lat   long  sqft_living15  sqft_lot15  \
# waterfront
# 0                  21434    21434  21434  21434          21434       21434
# 1                    163      163    163    163            163         163
#
#             price
# waterfront
# 0           21434
# 1             163

# %% [markdown]
# Buena representación

# %%
dataset.groupby("view").count()
# Out:
#          id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# view
# 0     19475     19475      19475        19475     19475   19475       19475
# 1       332       332        332          332       332     332         332
# 2       961       961        961          961       961     961         961
# 3       510       510        510          510       510     510         510
# 4       319       319        319          319       319     319         319
#
#       condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# view
# 0         19475  19475       19475          19475     19475         19475
# 1           332    332         332            332       332           332
# 2           961    961         961            961       961           961
# 3           510    510         510            510       510           510
# 4           319    319         319            319       319           319
#
# ...

# %% [markdown]
# Buena representación

# %%
dataset.groupby("condition").count()
# Out:
#               id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# condition
# 1             29        29         29           29        29      29
# 2            170       170        170          170       170     170
# 3          14020     14020      14020        14020     14020   14020
# 4           5677      5677       5677         5677      5677    5677
# 5           1701      1701       1701         1701      1701    1701
#
#            waterfront   view  grade  sqft_above  sqft_basement  yr_built  \
# condition
# 1                  29     29     29          29             29        29
# 2                 170    170    170         170            170       170
# 3               14020  14020  14020       14020          14020     14020
# 4                5677   5677   5677        5677           5677      5677
# 5                1701   1701   1701        1701           1701      1701
#
#            yr_renovated  zipcode    lat   long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# Buena representación

# %%
dataset.groupby("grade").count()
# Out:
#          id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# grade
# 3         1         1          1            1         1       1           1
# 4        27        27         27           27        27      27          27
# 5       242       242        242          242       242     242         242
# 6      2038      2038       2038         2038      2038    2038        2038
# 7      8974      8974       8974         8974      8974    8974        8974
# 8      6065      6065       6065         6065      6065    6065        6065
# 9      2615      2615       2615         2615      2615    2615        2615
# 10     1134      1134       1134         1134      1134    1134        1134
# 11      399       399        399          399       399     399         399
# 12       89        89         89           89        89      89          89
# 13       13        13         13           13        13      13          13
#
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("sqft_above").count()
# Out:
#             id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# sqft_above
# 370          1         1          1            1         1       1
# 380          1         1          1            1         1       1
# 390          1         1          1            1         1       1
# 410          1         1          1            1         1       1
# 420          2         2          2            2         2       2
# ...         ..       ...        ...          ...       ...     ...
# 7880         1         1          1            1         1       1
# 8020         1         1          1            1         1       1
# 8570         1         1          1            1         1       1
# 8860         1         1          1            1         1       1
# 9410         1         1          1            1         1       1
#
#             waterfront  view  condition  grade  sqft_basement  yr_built  \
# sqft_above
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("sqft_basement").count()
# Out:
#                   id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# sqft_basement
# 0              13110     13110      13110        13110     13110   13110
# 10                 2         2          2            2         2       2
# 20                 1         1          1            1         1       1
# 40                 4         4          4            4         4       4
# 50                11        11         11           11        11      11
# ...              ...       ...        ...          ...       ...     ...
# 3260               1         1          1            1         1       1
# 3480               1         1          1            1         1       1
# 3500               1         1          1            1         1       1
# 4130               1         1          1            1         1       1
# 4820               1         1          1            1         1       1
#
#                waterfront   view  condition  grade  sqft_above  yr_built  \
# ...

# %% [markdown]
# Buena representación

# %%
dataset.groupby("yr_built").count()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# yr_built
# 1900       87        87         87           87        87      87          87
# 1901       29        29         29           29        29      29          29
# 1902       27        27         27           27        27      27          27
# 1903       46        46         46           46        46      46          46
# 1904       45        45         45           45        45      45          45
# ...       ...       ...        ...          ...       ...     ...         ...
# 2011      130       130        130          130       130     130         130
# 2012      170       170        170          170       170     170         170
# 2013      201       201        201          201       201     201         201
# 2014      559       559        559          559       559     559         559
# 2015       38        38         38           38        38      38          38
#
# ...

# %% [markdown]
# Buena representación

# %%
dataset.groupby("yr_renovated").count()
# Out:
#                  id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# yr_renovated
# 0             20683     20683      20683        20683     20683   20683
# 1934              1         1          1            1         1       1
# 1940              2         2          2            2         2       2
# 1944              1         1          1            1         1       1
# 1945              3         3          3            3         3       3
# ...             ...       ...        ...          ...       ...     ...
# 2011             13        13         13           13        13      13
# 2012             11        11         11           11        11      11
# 2013             37        37         37           37        37      37
# 2014             91        91         91           91        91      91
# 2015             16        16         16           16        16      16
#
#               waterfront   view  condition  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# Buena representación

# %%
dataset.groupby("zipcode").count()
# Out:
#           id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# zipcode
# 98001    361       361        361          361       361     361         361
# 98002    199       199        199          199       199     199         199
# 98003    280       280        280          280       280     280         280
# 98004    317       317        317          317       317     317         317
# 98005    168       168        168          168       168     168         168
# ...      ...       ...        ...          ...       ...     ...         ...
# 98177    255       255        255          255       255     255         255
# 98178    262       262        262          262       262     262         262
# 98188    136       136        136          136       136     136         136
# 98198    280       280        280          280       280     280         280
# 98199    317       317        317          317       317     317         317
#
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("lat").count()
# Out:
#          id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# lat
# 47.1559   1         1          1            1         1       1           1
# 47.1593   1         1          1            1         1       1           1
# 47.1622   1         1          1            1         1       1           1
# 47.1647   1         1          1            1         1       1           1
# 47.1764   1         1          1            1         1       1           1
# ...      ..       ...        ...          ...       ...     ...         ...
# 47.7771   2         2          2            2         2       2           2
# 47.7772   3         3          3            3         3       3           3
# 47.7774   1         1          1            1         1       1           1
# 47.7775   3         3          3            3         3       3           3
# 47.7776   3         3          3            3         3       3           3
#
# ...

# %% [markdown]
# mala representación

# %%
dataset.groupby("long").count()
# Out:
#           id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# long
# -122.519   1         1          1            1         1       1           1
# -122.515   1         1          1            1         1       1           1
# -122.514   1         1          1            1         1       1           1
# -122.512   1         1          1            1         1       1           1
# -122.511   2         2          2            2         2       2           2
# ...       ..       ...        ...          ...       ...     ...         ...
# -121.325   1         1          1            1         1       1           1
# -121.321   1         1          1            1         1       1           1
# -121.319   1         1          1            1         1       1           1
# -121.316   1         1          1            1         1       1           1
# -121.315   2         2          2            2         2       2           2
#
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("sqft_living15").count()
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# sqft_living15
# 399             1         1          1            1         1       1
# 460             2         2          2            2         2       2
# 620             2         2          2            2         2       2
# 670             1         1          1            1         1       1
# 690             2         2          2            2         2       2
# ...            ..       ...        ...          ...       ...     ...
# 5600            1         1          1            1         1       1
# 5610            1         1          1            1         1       1
# 5790            6         6          6            6         6       6
# 6110            1         1          1            1         1       1
# 6210            1         1          1            1         1       1
#
#                waterfront  view  condition  grade  sqft_above  sqft_basement  \
# sqft_living15
# ...

# %% [markdown]
# Mala representación

# %%
dataset.groupby("price").count()
# Out:
#          id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# price
# 78000     1         1          1            1         1       1           1
# 80000     1         1          1            1         1       1           1
# 81000     1         1          1            1         1       1           1
# 82000     1         1          1            1         1       1           1
# 82500     1         1          1            1         1       1           1
# ...      ..       ...        ...          ...       ...     ...         ...
# 5350000   1         1          1            1         1       1           1
# 5570000   1         1          1            1         1       1           1
# 6890000   1         1          1            1         1       1           1
# 7060000   1         1          1            1         1       1           1
# 7700000   1         1          1            1         1       1           1
#
# ...

# %% [markdown]
# # Fin de contar casas

# %% [markdown]
# # Ej 8

# %%
new_df = dataset[(dataset["bathrooms"]>3)&(dataset["price"]>300000)&(dataset["floors"]==1)&(dataset["waterfront"]==0)&(dataset["condition"]>2)&(dataset["grade"]>4)&((dataset["bedrooms"]==3)|(dataset["bedrooms"]==4))]
new_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420    101930     1.0
# 313    4139480200         4       3.25         4290     12103     1.0
# 314    4139480200         4       3.25         4290     12103     1.0
# 409    1560930070         4       3.50         2840     40139     1.0
# 792    8081020370         4       3.50         3550     11000     1.0
# ...           ...       ...        ...          ...       ...     ...
# 20713  3758900023         4       3.25         3810      8519     1.0
# 20905  3864000120         4       3.25         3780     10099     1.0
# 20957  1239400650         4       3.50         4700     10183     1.0
# 21271   123059127         4       3.25         2730     54014     1.0
# 21514  8964800330         4       3.75         5090     14823     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
dataset["price"].mean()*2
# Out:
# 1080593.147011159

# %%
new_df = dataset[dataset["price"]>1080593.147011159]
new_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 5      7237550310         4       4.50         5420    101930     1.0
# 21     2524049179         3       2.75         3050     44867     1.0
# 49      822039084         3       2.50         2753     65005     1.0
# 69     1802000060         5       2.25         3200     20158     1.0
# 91     5036300431         5       2.75         3520      6353     2.0
# ...           ...       ...        ...          ...       ...     ...
# 21560  9253900271         5       4.50         4850     10584     2.0
# 21574  7430200100         4       3.50         4910      9444     1.5
# 21577  8672200110         5       3.75         4170      8142     2.0
# 21581   191100405         4       3.25         3410     10125     2.0
# 21584   249000205         5       3.75         4470      8088     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
new_df = dataset[((dataset["bedrooms"]==3)|(dataset["bedrooms"]==4))]
new_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520         3       1.00         1180      5650     1.0
# 1      6414100192         3       2.25         2570      7242     2.0
# 3      2487200875         4       3.00         1960      5000     1.0
# 4      1954400510         3       2.00         1680      8080     1.0
# 5      7237550310         4       4.50         5420    101930     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21590  7936000429         4       3.50         3510      7200     2.0
# 21591  2997800021         3       2.50         1310      1294     2.0
# 21592   263000018         3       2.50         1530      1131     3.0
# 21593  6600060120         4       2.50         2310      5813     2.0
# 21595   291310100         3       2.50         1600      2388     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
new_df["price"].mean()
# Out:
# 536014.44612714

# %%
dataset["price"].mean()-new_df["price"].mean()
# Out:
# 4282.127378439531

# %% [markdown]
# Diferencia de media == 4282.127378439531

# %%
dataset["zipcode"].unique()
# Out:
# array([98178, 98125, 98028, 98136, 98074, 98053, 98003, 98198, 98146,
#        98038, 98007, 98115, 98107, 98126, 98019, 98103, 98002, 98133,
#        98040, 98092, 98030, 98119, 98112, 98052, 98027, 98117, 98058,
#        98001, 98056, 98166, 98023, 98070, 98148, 98105, 98042, 98008,
#        98059, 98122, 98144, 98004, 98005, 98034, 98075, 98116, 98010,
#        98118, 98199, 98032, 98045, 98102, 98077, 98108, 98168, 98177,
#        98065, 98029, 98006, 98109, 98022, 98033, 98155, 98024, 98011,
#        98031, 98106, 98072, 98188, 98014, 98055, 98039], dtype=int64)

# %%
new_df = dataset[dataset["yr_renovated"]!=0]
new_df
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1      6414100192         3       2.25         2570      7242     2.0
# 35     9547205180         3       2.50         2300      3060     1.5
# 95     1483300570         4       2.50         3300     10250     1.0
# 103    2450000295         3       2.50         2920      8113     2.0
# 115    3626039325         3       3.50         4380      6350     2.0
# ...           ...       ...        ...          ...       ...     ...
# 19606  7351200295         3       1.75         1760      6788     2.0
# 20041   126039256         3       2.00         1520      5040     2.0
# 20428  4305600360         4       2.50         2400      9612     1.0
# 20431  3319500628         3       1.50         1010      1546     2.0
# 20946  1278000210         2       1.00          828      4524     1.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
dataset3 = dataset

# %%
dataset3 = dataset3.sort_values(by=["price"],ascending=False)
dataset3.head(15)
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 7245   6762700020         6       8.00        12050     27600     2.5
# 3910   9808700762         5       4.50        10040     37325     2.0
# 9245   9208900037         6       7.75         9890     31374     2.0
# 4407   2470100110         5       5.75         9200     35069     2.0
# 1446   8907500070         5       5.00         8000     23985     2.0
# 1313   7558700030         6       6.00         7390     24829     2.0
# 1162   1247600105         5       5.25         8010     45517     2.0
# 8085   1924059029         5       6.75         9640     13068     1.0
# 2624   7738500731         5       5.50         6640     40014     2.0
# 8629   3835500195         4       3.00         6430     27517     2.0
# 12358  6065300370         5       6.00         7440     21540     2.0
# 4145   6447300265         4       5.50         7080     16573     2.0
# ...

# %%
row=10
#display(dataset3.loc[row:row])
display(dataset3.iloc[row:row+1])
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 12358  6065300370         5        6.0         7440     21540     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 12358           0     0          3     12        5550           1890
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 12358      2003             0    98006  47.5692 -122.189           4740
#
#        sqft_lot15    price
# 12358       19329  4210000
